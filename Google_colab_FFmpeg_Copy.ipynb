# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !cd "/content"
# !mkdir temp
# !cd temp
# !ffmpeg -i "" -codec copy Downloaded.mp4

# %%
import shutil

source_dir = r"/content/temp"
destination_dir = r"/content/drive/root"
shutil.copytree(source_dir, destination_dir, dirs_exist_ok=True)
